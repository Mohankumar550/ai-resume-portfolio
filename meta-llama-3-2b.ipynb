# %%
pip install transformers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
pip install transformers accelerate

# %%
pip install huggingface_hub

# %%
from huggingface_hub import snapshot_download

# Your Hugging Face access token (best to store this securely)
hf_token = "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"  # 🔒 Regenerate this now

# The gated LLaMA 3 model
model_id = "meta-llama/Llama-3.2-1B-Instruct"

# Local path to save model
local_path = "./models/llama3-2"

# Download the model
model_path = snapshot_download(
    repo_id=model_id,
    local_dir=local_path,
    local_dir_use_symlinks=False,
    token=hf_token
)

print(f"Model downloaded to: {model_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:980: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# LICENSE.txt:   0%|          | 0.00/7.71k [00:00<?, ?B/s]
# original/consolidated.00.pth:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# USE_POLICY.md:   0%|          | 0.00/6.02k [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "meta-llama/Llama-3.2-1B-Instruct"

# Local path to save model
local_path = "./models/llama3-2"

tokenizer = AutoTokenizer.from_pretrained(local_path)
model = AutoModelForCausalLM.from_pretrained(local_path)

# %%
prompt = "Explain what a language model is in simple terms."

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_new_tokens=150)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Explain what a language model is in simple terms. A language model is a computer program that can understand and generate human language. It's like a super smart assistant that can read and write in any language.
#
# Think of it like a conversational AI that can:
#
# * Understand what you say
# * Understand what you mean
# * Respond to your questions
# * Even learn and improve over time
#
# Language models are trained on vast amounts of text data, which allows them to learn patterns and relationships between words, phrases, and sentences. They can then use this knowledge to generate text, answer questions, or even create new content.
#
# Some examples of language models include:
#
# * Chatbots like Siri or Alexa
# * Virtual assistants like Google Assistant
# * Text generators like language translation tools
# * Even some websites that use

# %%
pip install -U bitsandbytes transformers accelerate peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 kB 16.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.7.0
#     Uninstalling accelerate-1.7.0:
#       Successfully uninstalled accelerate-1.7.0
# ...

# %%
import json

# Load the JSON array
with open("./resume_qa.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Save as JSONL
with open("resume_qa_dataset.jsonl", "w", encoding="utf-8") as f:
    for entry in data:
        f.write(json.dumps(entry) + "\n")

print("✅ Successfully converted to JSONL format: resume_qa_dataset.jsonl")
# Out:
# ✅ Successfully converted to JSONL format: resume_qa_dataset.jsonl

# %%
# !pip install -U bitsandbytes accelerate transformers datasets peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %%
from transformers import (
    AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig,
    TrainingArguments, Trainer, DataCollatorForLanguageModeling
)
from peft import (
    prepare_model_for_kbit_training, LoraConfig, get_peft_model
)
from datasets import load_dataset, Features, Value

# === Dataset schema ===
features = Features({
    "instruction": Value("string"),
    "input": Value("string"),
    "output": Value("string")
})

# === Load your dataset ===
dataset = load_dataset(
    "json",
    data_files="resume_qa_dataset.jsonl",
    split="train",
    features=features
)

# === Load model/tokenizer ===
model_path = "./models/llama3-2"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
    bnb_4bit_use_double_quant=True
)

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(
    model_path,
    quantization_config=bnb_config,
    device_map="auto"
)

# === LoRA config and wrapping ===
model = prepare_model_for_kbit_training(model)

peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, peft_config)

# === Tokenization ===
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

def tokenize(example):
    prompt = example["instruction"]
    if example["input"]:
        prompt += "\n" + example["input"]
    full = prompt + "\n" + example["output"]
    return tokenizer(full, truncation=True, padding="max_length", max_length=512)
tokenized_dataset = dataset.map(tokenize)

# === Training settings ===
training_args = TrainingArguments(
    output_dir="./llama3-resume-finetuned",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=2,
    learning_rate=2e-4,
    num_train_epochs=2,
    fp16=True,
    logging_steps=10,
    save_strategy="epoch",
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)
)

# === Train! ===
trainer.train()

# === Save results ===
model.save_pretrained("./llama3-resume-finetuned")
tokenizer.save_pretrained("./llama3-resume-finetuned")
# Out:
# Map:   0%|          | 0/79 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_path = "./llama3-resume-finetuned"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

while True:
    question = input("Ask your resume assistant: ")
    prompt = f"""ou are Mohankumar’s personal assistant. Only answer based on his actual resume data below.


Q: {question}
A:"""

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(
        **inputs,
        max_length=150,
        do_sample=True,
        temperature=0.1,
        top_p=0.9,
        pad_token_id=tokenizer.pad_token_id,
    )
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    answer = answer.split("Output:")[-1].strip()
    print(f"Answer: {answer}\n")
# Out:
# Ask your resume assistant: how's mohankumar ?
# Answer: ou are Mohankumar’s personal assistant. Only answer based on his actual resume data below.
#
#
# Q: how's mohankumar?
# A: he is doing great, thanks for asking. just busy with work and personal stuff. how can i help you today?
#
# Ask your resume assistant: give me best of mohankumar
# Answer: ou are Mohankumar’s personal assistant. Only answer based on his actual resume data below.
#
#
# Q: give me best of mohankumar
# ...
